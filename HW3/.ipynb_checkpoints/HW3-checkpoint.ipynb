# %% [markdown]
# **CS547 HW3 Group37**
# Yue Cui
# Gaoyu Liu

# %% [markdown]
# **Single Quadrant Case (1st quadrant)**
#
# Alternative Representation 1:
#
# $$ \boldsymbol{1}_{\mathbb{R}_{+} \  \times \  \mathbb{R}_{+}} \ (x,y) \approx s_{\varepsilon}(s_{\varepsilon}(-s_{\varepsilon}(-x)+s_{\varepsilon}(y)-\frac{1}{2})-\frac{1}{2}) $$
#
# \begin{equation*}
# M^{(1)} =
# \begin{bmatrix}
# -1 & 0 \\
# 0 & 1
# \end{bmatrix} \bigg/ \varepsilon
# \quad
# B^{(1)} =
# \begin{bmatrix}
# 0 \\
# 0
# \end{bmatrix}
# \end{equation*}
#
# \begin{equation*}
# M^{(2)} =
# \begin{bmatrix}
# -1 & 1 \\
# 0 & 0
# \end{bmatrix} \bigg/ \varepsilon
# \quad
# B^{(2)} =
# \begin{bmatrix}
# -\frac{1}{2} \\
# 0
# \end{bmatrix} \bigg/ \varepsilon
# \end{equation*}
#
# \begin{equation*}
# M^{(3)} =
# \begin{bmatrix}
# 1 & 0
# \end{bmatrix} \big/ \varepsilon
# \quad
# B^{(3)} = -\frac{1}{2\varepsilon}
# \end{equation*}

# %% [markdown]
# Alternative Representation 2:
#
# $$ \boldsymbol{1}_{\mathbb{R}_{+} \  \times \  \mathbb{R}_{+}} \ (x,y) \approx s_{\varepsilon}(s_{\varepsilon}(s_{\varepsilon}(x)-s_{\varepsilon}(-y)-\frac{1}{2})-\frac{1}{2}) $$
#
# \begin{equation*}
# M^{(1)} =
# \begin{bmatrix}
# 1 & 0 \\
# 0 & -1
# \end{bmatrix} \bigg/ \varepsilon
# \quad
# B^{(1)} =
# \begin{bmatrix}
# 0 \\
# 0
# \end{bmatrix}
# \end{equation*}
#
# \begin{equation*}
# M^{(2)} =
# \begin{bmatrix}
# 1 & -1 \\
# 0 & 0
# \end{bmatrix} \bigg/ \varepsilon
# \quad
# B^{(2)} =
# \begin{bmatrix}
# -\frac{1}{2} \\
# 0
# \end{bmatrix} \bigg/ \varepsilon
# \end{equation*}
#
# \begin{equation*}
# M^{(3)} =
# \begin{bmatrix}
# 1 & 0
# \end{bmatrix} \big/ \varepsilon
# \quad
# B^{(3)} = -\frac{1}{2\varepsilon}
# \end{equation*}

# %% [markdown]
# Alternative Representation 3:
#
#
# $$ \boldsymbol{1}_{\mathbb{R}_{+} \  \times \  \mathbb{R}_{+}} \ (x,y) \approx s_{\varepsilon}(s_{\varepsilon}(-s_{\varepsilon}(-x)-s_{\varepsilon}(-y)+\frac{1}{2})-\frac{1}{2}) $$
#
# \begin{equation*}
# M^{(1)} =
# \begin{bmatrix}
# -1 & 0 \\
# 0 & -1
# \end{bmatrix} \bigg/ \varepsilon
# \quad
# B^{(1)} =
# \begin{bmatrix}
# 0 \\
# 0
# \end{bmatrix}
# \end{equation*}
#
# \begin{equation*}
# M^{(2)} =
# \begin{bmatrix}
# -1 & -1 \\
# 0 & 0
# \end{bmatrix} \bigg/ \varepsilon
# \quad
# B^{(2)} =
# \begin{bmatrix}
# \frac{1}{2} \\
# 0
# \end{bmatrix} \bigg/ \varepsilon
# \end{equation*}
#
# \begin{equation*}
# M^{(3)} =
# \begin{bmatrix}
# 1 & 0
# \end{bmatrix} \big/ \varepsilon
# \quad
# B^{(3)} = -\frac{1}{2\varepsilon}
# \end{equation*}

# %% [markdown]
# **Complements of Single Quadrants Case (1st quadrants 0)**
#
# Alternative Representation 1:
#
# $$ \boldsymbol{1}_{\mathbb{R}^2 \ \backslash (\mathbb{R}_{+} \  \times \  \mathbb{R}_{+}) }\  (x,y) \approx s_{\varepsilon}(s_{\varepsilon}(-s_{\varepsilon}(x)-s_{\varepsilon}(y)+\frac{3}{2})-\frac{1}{2}) $$
#
# \begin{equation*}
# M^{(1)} =
# \begin{bmatrix}
# 1 & 0 \\
# 0 & 1
# \end{bmatrix} \bigg/ \varepsilon
# \quad
# B^{(1)} =
# \begin{bmatrix}
# 0 \\
# 0
# \end{bmatrix}
# \end{equation*}
#
# \begin{equation*}
# M^{(2)} =
# \begin{bmatrix}
# -1 & -1 \\
# 0 & 0
# \end{bmatrix} \bigg/ \varepsilon
# \quad
# B^{(2)} =
# \begin{bmatrix}
# \frac{3}{2} \\
# 0
# \end{bmatrix} \bigg/ \varepsilon
# \end{equation*}
#
# \begin{equation*}
# M^{(3)} =
# \begin{bmatrix}
# 1 & 0
# \end{bmatrix} \big/ \varepsilon
# \quad
# B^{(3)} = -\frac{1}{2\varepsilon}
# \end{equation*}

# %% [markdown]
# Alternative Representation 2:
#
# $$ \boldsymbol{1}_{\mathbb{R}^2 \ \backslash (\mathbb{R}_{+} \  \times \  \mathbb{R}_{+}) }\  (x,y) \approx s_{\varepsilon}(s_{\varepsilon}(-s_{\varepsilon}(x)+s_{\varepsilon}(-y)+\frac{1}{2})-\frac{1}{2}) $$
#
# \begin{equation*}
# M^{(1)} =
# \begin{bmatrix}
# 1 & 0 \\
# 0 & -1
# \end{bmatrix} \bigg/ \varepsilon
# \quad
# B^{(1)} =
# \begin{bmatrix}
# 0 \\
# 0
# \end{bmatrix}
# \end{equation*}
#
# \begin{equation*}
# M^{(2)} =
# \begin{bmatrix}
# -1 & 1 \\
# 0 & 0
# \end{bmatrix} \bigg/ \varepsilon
# \quad
# B^{(2)} =
# \begin{bmatrix}
# \frac{1}{2} \\
# 0
# \end{bmatrix} \bigg/ \varepsilon
# \end{equation*}
#
# \begin{equation*}
# M^{(3)} =
# \begin{bmatrix}
# 1 & 0
# \end{bmatrix} \big/ \varepsilon
# \quad
# B^{(3)} = -\frac{1}{2\varepsilon}
# \end{equation*}
